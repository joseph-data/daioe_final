# %% [markdown]
# # SCB Data Pull & Weight Computation

# %%
import pandas as pd 
from pyscbwrapper import SCB
from pathlib import Path

#ROOT = Path(__file__).resolve().parents[1]
ROOT = Path.cwd().resolve().parents[1]

# %%
TAX_ID = 'ssyk2012' 

TABLES = {
    "ssyk2012_tab": ("en", "AM", "AM0208", "AM0208E", "YREG51BAS"),
    "ssyk96_tab": ("en", "AM", "AM0208", "AM0208E", "YREG33"),
}

# %%
scb = SCB(*TABLES[f"{TAX_ID}_tab"])

# %%
scb.info()
# Out:
# {'title': 'Employees, number by occupation (SSYK 2012), level of education SUN 2020, age, sex, observations and year',
#  'variables': [{'code': 'Yrke2012',
#    'text': 'occupation (SSYK 2012)',
#    'values': ['0110',
#     '0210',
#     '0310',
#     '1111',
#     '1112',
#     '1113',
#     '1120',
#     '1211',
#     '1212',
#     '1221',
#     '1222',
#     '1230',
#     '1241',
#     '1242',
#     '1251',
#     '1252',
#     '1291',
#     '1292',
#     '1311',
#     '1312',
#     '1321',
#     '1322',
#     '1331',
#     '1332',
#     '1341',
#     '1342',
#     '1351',
#     '1352',
#     '1361',
#     '1362',
#     '1371',
#     '1372',
#     '1380',
#     '1411',
#     '1412',
#     '1421',
#     '1422',
#     '1491',
#     '1492',
#     '1511',
#     '1512',
#     '1521',
#     '1522',
#     '1531',
#     '1532',
#     '1540',
#     '1591',
#     '1592',
#     '1611',
#     '1612',
#     '1711',
#     '1712',
#     '1721',
#     '1722',
#     '1731',
#     '1732',
#     '1741',
#     '1742',
#     '1791',
#     '1792',
#     '2111',
#     '2112',
#     '2113',
#     '2114',
#     '2121',
#     '2122',
#     '2131',
#     '2132',
#     '2133',
#     '2134',
#     '2135',
#     '2141',
#     '2142',
#     '2143',
#     '2144',
#     '2145',
#     '2146',
#     '2149',
#     '2161',
#     '2162',
#     '2163',
#     '2164',
#     '2171',
#     '2172',
#     '2173',
#     '2179',
#     '2181',
#     '2182',
#     '2183',
#     '2211',
#     '2212',
#     '2213',
#     '2219',
#     '2221',
#     '2222',
#     '2223',
#     '2224',
#     '2225',
#     '2226',
#     '2227',
#     '2228',
#     '2231',
#     '2232',
#     '2233',
#     '2234',
#     '2235',
#     '2239',
#     '2241',
#     '2242',
#     '2250',
#     '2260',
#     '2271',
#     '2272',
#     '2273',
#     '2281',
#     '2282',
#     '2283',
#     '2284',
#     '2289',
#     '2311',
#     '2312',
#     '2313',
#     '2314',
#     '2319',
#     '2320',
#     '2330',
#     '2341',
#     '2342',
#     '2343',
#     '2351',
#     '2352',
#     '2359',
#     '2411',
#     '2412',
#     '2413',
#     '2414',
#     '2415',
#     '2419',
#     '2421',
#     '2422',
#     '2423',
#     '2431',
#     '2432',
#     '2511',
#     '2512',
#     '2513',
#     '2514',
#     '2515',
#     '2516',
#     '2519',
#     '2611',
#     '2612',
#     '2613',
#     '2614',
#     '2615',
#     '2619',
#     '2621',
#     '2622',
#     '2623',
#     '2641',
#     '2642',
#     '2643',
#     '2651',
#     '2652',
#     '2653',
#     '2654',
#     '2655',
#     '2661',
#     '2662',
#     '2663',
#     '2669',
#     '2671',
#     '2672',
#     '3111',
#     '3112',
#     '3113',
#     '3114',
#     '3115',
#     '3116',
#     '3117',
#     '3119',
#     '3121',
#     '3122',
#     '3151',
#     '3152',
#     '3153',
#     '3154',
#     '3155',
#     '3211',
#     '3212',
#     '3213',
#     '3214',
#     '3215',
#     '3230',
#     '3240',
#     '3250',
#     '3311',
#     '3312',
#     '3313',
#     '3314',
#     '3321',
#     '3322',
#     '3323',
#     '3324',
#     '3331',
#     '3332',
#     '3333',
#     '3334',
#     '3335',
#     '3339',
#     '3341',
#     '3342',
#     '3343',
#     '3351',
#     '3352',
#     '3353',
#     '3354',
#     '3355',
#     '3359',
#     '3360',
#     '3411',
#     '3412',
#     '3421',
#     '3422',
#     '3423',
#     '3424',
#     '3431',
#     '3432',
#     '3433',
#     '3439',
#     '3441',
#     '3449',
#     '3451',
#     '3452',
#     '3511',
#     '3512',
#     '3513',
#     '3514',
#     '3515',
#     '3521',
#     '3522',
#     '4111',
#     '4112',
#     '4113',
#     '4114',
#     '4115',
#     '4116',
#     '4117',
#     '4119',
#     '4211',
#     '4212',
#     '4221',
#     '4222',
#     '4223',
#     '4224',
#     '4225',
#     '4226',
#     '4321',
#     '4322',
#     '4323',
#     '4410',
#     '4420',
#     '4430',
#     '5111',
#     '5112',
#     '5113',
#     '5120',
#     '5131',
#     '5132',
#     '5141',
#     '5142',
#     '5143',
#     '5144',
#     '5149',
#     '5151',
#     '5152',
#     '5161',
#     '5169',
#     '5221',
#     '5222',
#     '5223',
#     '5224',
#     '5225',
#     '5226',
#     '5227',
#     '5230',
#     '5241',
#     '5242',
#     '5311',
#     '5312',
#     '5321',
#     '5322',
#     '5323',
#     '5324',
#     '5325',
#     '5326',
#     '5330',
#     '5341',
#     '5342',
#     '5343',
#     '5349',
#     '5350',
#     '5411',
#     '5412',
#     '5413',
#     '5414',
#     '5419',
#     '6111',
#     '6112',
#     '6113',
#     '6121',
#     '6122',
#     '6129',
#     '6130',
#     '6210',
#     '6221',
#     '6222',
#     '7111',
#     '7112',
#     '7113',
#     '7114',
#     '7115',
#     '7116',
#     '7119',
#     '7121',
#     '7122',
#     '7123',
#     '7124',
#     '7125',
#     '7126',
#     '7131',
#     '7132',
#     '7133',
#     '7134',
#     '7211',
#     '7212',
#     '7213',
#     '7214',
#     '7215',
#     '7221',
#     '7222',
#     '7223',
#     '7224',
#     '7231',
#     '7232',
#     '7233',
#     '7311',
#     '7312',
#     '7319',
#     '7321',
#     '7322',
#     '7323',
#     '7411',
#     '7412',
#     '7413',
#     '7420',
#     '7521',
#     '7522',
#     '7523',
#     '7531',
#     '7532',
#     '7533',
#     '7534',
#     '7611',
#     '7612',
#     '7613',
#     '7619',
#     '8111',
#     '8112',
#     '8113',
#     '8114',
#     '8115',
#     '8116',
#     '8121',
#     '8122',
#     '8129',
#     '8131',
#     '8132',
#     '8141',
#     '8142',
#     '8143',
#     '8151',
#     '8159',
#     '8161',
#     '8162',
#     '8163',
#     '8169',
#     '8171',
#     '8172',
#     '8173',
#     '8174',
#     '8181',
#     '8189',
#     '8191',
#     '8192',
#     '8193',
#     '8199',
#     '8211',
#     '8212',
#     '8213',
#     '8214',
#     '8219',
#     '8311',
#     '8312',
#     '8321',
#     '8329',
#     '8331',
#     '8332',
#     '8341',
#     '8342',
#     '8343',
#     '8344',
#     '8350',
#     '9111',
#     '9119',
#     '9120',
#     '9210',
#     '9310',
#     '9320',
#     '9331',
#     '9332',
#     '9411',
#     '9412',
#     '9413',
#     '9520',
#     '9610',
#     '9621',
#     '9622',
#     '9629',
#     '0002'],
#    'valueTexts': ['Commissioned armed forces officers',
#     'Non-commissioned armed forces officers',
#     'Armed forces occupation, other ranks',
#     'Legislators',
#     'Senior government officials',
#     'Senior officials of special-interest organisations',
#     'Directors and chief executives',
#     'Finance managers, level 1',
#     'Finance managers, level 2',
#     'Human resource managers, level 1',
#     'Human resource managers, level 2',
#     'Administration and planning managers',
#     'Information, communication and public relations managers, level 1',
#     'Information, communication and public relations managers, level 2',
#     'Sales and marketing managers, level 1',
#     'Sales and marketing managers, level 2',
#     'Administration and service managers not elsewhere classified, level 1',
#     'Administration and service managers not elsewhere classified, level 2',
#     'Information and communications technology service managers, level 1',
#     'Information and communications technology service managers, level 2',
#     'Supply, logistics and transport managers, level 1',
#     'Supply, logistics and transport managers, level 2',
#     'Research and development managers, level 1',
#     'Research and development managers, level 2',
#     'Architectural and engineering managers, level 1',
#     'Architectural and engineering managers, level 2',
#     'Real estate and head of administration managers, level 1',
#     'Real estate and head of administration managers, level 2',
#     'Production managers in construction and mining, level 1',
#     'Production managers in construction and mining, level 2',
#     'Production managers in manufacturing, level 1',
#     'Production managers in manufacturing, level 2',
#     'Forestry and agricultural production managers',
#     'Primary and secondary schools and adult education managers, level 1',
#     'Headmasters, level 2',
#     'Department managers in pre-school, level 1',
#     'Pre-school managers, level 2',
#     'Department managers in education not elsewhere classified, level 1',
#     'Operations managers in education not elsewhere classified, level 2',
#     'Clinical and operations managers in health care, level 1',
#     'Department and unit managers in health care, level 2',
#     'Department managers in social and curative care, level 1',
#     'Unit managers in social and curative care, level 2',
#     'Department managers in elderly care, level 1',
#     'Unit managers in elderly care, level 2',
#     'Managers and leaders within religious bodies',
#     'Managers in public services not elsewhere classified, level 1',
#     'Operations managers in public services not elsewhere classified, level 2',
#     'Financial and insurance managers, level 1',
#     'Financial and insurance managers, level 2',
#     'Hotel and conference managers, level 1',
#     'Hotel and conference managers, level 2',
#     'Restaurant managers, level 1',
#     'Restaurant managers, level 2',
#     'Retail and wholesale trade managers, level 1',
#     'Retail and wholesale trade managers, level 2',
#     'Sports, leisure and wellness managers, level 1',
#     'Sports, leisure and wellness managers, level 2',
#     'Other services managers not elsewhere classified, level 1',
#     'Other services managers not elsewhere classified, level 2',
#     'Physicists and astronomers',
#     'Meteorologists',
#     'Chemists',
#     'Geologists, geophysicists and related professionals',
#     'Mathematicians and actuaries',
#     'Statisticians',
#     'Cell and molecular biologists and related professionals',
#     'Plant and animal biologists',
#     'Pharmacologists and related professionals',
#     'Agricultural professionals',
#     'Forestry professionals',
#     'Engineering professionals in logistics and production',
#     'Engineering professionals in building construction',
#     'Engineering professionals in electrical, electronics and telecommunications',
#     'Engineering professionals in mechanical technology',
#     'Engineering professionals in chemical technology',
#     'Engineering professionals in mining-, metallurgy technology and related professionals',
#     'Engineering professionals not elsewhere classified',
#     'Architects ',
#     'Landscape architects',
#     'Architects, town and traffic planners',
#     'Cartographers and surveyors',
#     'Product designers, industrial',
#     'Graphic designers',
#     'Game and digital media designers',
#     'Fashion designers and related professionals',
#     'Environmental and occupational health and hygiene professionals',
#     'Environmental and occupational health inspectors',
#     'Environmental protection professionals',
#     'Specialist physicians',
#     'Resident physicians',
#     'General medical practitioners',
#     'Other physicians',
#     'Professional nurses',
#     'Professional midwifes',
#     'Anaesthesia nurses',
#     'District nurses',
#     'Psychiatry nurses',
#     'Nurses - Ambulance ',
#     'Nurses - geriatric',
#     'Nurses - Intensive care ',
#     'Nurses - operation',
#     'Nurses - children',
#     'Nurses - school',
#     'Company nurses',
#     'Nurses - radiology ',
#     'Other specialist nurses',
#     'Psychologists',
#     'Psychotherapists',
#     'Veterinarians',
#     'Dentists',
#     'Chiropractors and naprapaths',
#     'Physiotherapists',
#     'Occupational therapist',
#     'Pharmacists',
#     'Dieticians',
#     'Audiologists and speech therapists',
#     'Opticians',
#     'Health professionals not elsewhere classified',
#     'Professors',
#     'University and higher education lecturers',
#     'Research assistants',
#     'PhD Students',
#     'University and higher education teachers not elsewhere classified',
#     'Vocational education teachers',
#     'Secondary education teachers',
#     'Primary school teachers',
#     'Recreation leaders',
#     'Preschool teachers',
#     'Special teachers and special needs teachers',
#     'School counsellor ',
#     'Teaching professionals not elsewhere classified',
#     'Accountants',
#     'Financial controllers',
#     'Financial and investment advisers',
#     'Traders and fund administrators',
#     'Economists and macro analyst',
#     'Economists not elsewhere classified',
#     'Management and organisation analysts',
#     'Policy administration professionals',
#     'Personnel and human resources specialist',
#     'Advertising and marketing professionals',
#     'Public relations professionals',
#     'System analysts and ICT-architects',
#     'Software- and system developers',
#     'Games and digital media developers',
#     'System testers and test managers',
#     'System administrators',
#     'Security specialists (ICT)',
#     'ICT-specialist professionals not elsewhere classified ',
#     'Lawyers',
#     'Judges',
#     'Prosecutors',
#     'Business and company lawyers',
#     'Management and organisation lawyers',
#     'Legal professionals not elsewhere classified',
#     'Museum curators and related professionals',
#     'Librarians and archivists',
#     'Archaeologists and related professionals',
#     'Authors and related writers',
#     'Journalists and related professionals',
#     'Translators, interpreters and other linguists',
#     'Visual artists and related artists',
#     'Musicians, singers and composers',
#     'Choreographers and dancers',
#     'Film, stage and related directors and producers',
#     'Actors',
#     'Social work professionals',
#     'Counselling professionals',
#     'Assistance analysts',
#     'Social work professions not elsewhere classified',
#     'Religious professionals',
#     'Deacons',
#     'Industrial, logistics and production planning engineering technicians',
#     'Construction and manufacturing engineering technicians',
#     'Electronics engineering technicians',
#     'Mechanical engineering technicians',
#     'Chemical engineering technicians',
#     'Mining and metallurgical technicians',
#     'GIS and cartographic engineers',
#     'Technicians not elsewhere classified',
#     'Construction and mining supervisors',
#     'Manufacturing supervisors',
#     'Ships engineers',
#     'Ships deck officers ',
#     'Aircraft pilots and related associate professionals',
#     'Air traffic controllers',
#     'Aircraft maintenance technician ',
#     'Medical imaging and therapeutic equipment technicians',
#     'Medical and pathology laboratory technicians',
#     'Prescriptionists',
#     'Dental and orthopaedic technicians ',
#     'Chemical and physical science technicians',
#     'Complementary medicine therapists and associate professionals',
#     'Veterinary assistants',
#     'Dental hygienists',
#     'Finance dealers and brokers',
#     'Bank clerk',
#     'Accounting associate professionals',
#     'Claims assessor and valuers',
#     'Insurance sellers and insurance advisers',
#     'Commercial sales representatives',
#     'Buyers and purchasers',
#     'Orders coordinator',
#     'Forwarding agents and transport brokers',
#     'Event and travel planners',
#     'Employment officers',
#     'Real estate agents',
#     'Real estate administrators',
#     'Business services agents not elsewhere classified',
#     'Office supervisors',
#     'Legal secretaries',
#     'Administrative and specialized secretaries',
#     'Customs and coast guard officers',
#     'Tax officials',
#     'Government social benefits officials',
#     'Safety and quality inspectors',
#     'Fire and building inspectors',
#     'Administrative secretaries and related associate professionals',
#     'Police Officers',
#     'Social work associate professionals',
#     'Religious associate professionals',
#     'Professional Athletes',
#     'Sports coachers and instructors',
#     'Recreation and related associate professionals',
#     'Wellness consultants and health educators',
#     'Photographers',
#     'Interior designers and decorators, scenographers',
#     'Stage managers and related associate professionals',
#     'Artistic and cultural associate professionals not elsewhere classified',
#     'Driving instructors',
#     'Other teaching associate professionals',
#     'Chefs and sous-chefs',
#     'Catering directors',
#     'ICT operations technicians',
#     'ICT support technicians',
#     'System administrators',
#     'Computer network and systems technicians',
#     'Webmasters and web administrators',
#     'Broadcasting and audio-visual technicians',
#     'Light, sound and stage technicians',
#     'Economic assistants',
#     'Payroll and personnel clerks',
#     'Back office-staff',
#     'Market and sales assistants',
#     'Purchasing and ordering assistants',
#     'School assistants',
#     'Medical secretaries and related associate professionals',
#     'Office clerks not elsewhere classified',
#     'Croupiers, bookmakers and related workers',
#     'Debt-collectors, pawnbrokers and related workers',
#     'Travel agents and related clerks',
#     'Customer Service Information Clerks',
#     'Telephonist-switchboard operators',
#     'Hotel receptionists',
#     'Office receptionists',
#     'Survey and market research interviewers',
#     'Warehouse and terminal supervisors',
#     'Warehouse and terminal Staff',
#     'Transport coordinators',
#     'Library and filing clerks',
#     'Postmen and postal facility workers',
#     'Elected representatives',
#     'Cabin crew',
#     'Train attendants, persons responsible on board',
#     'Travel guides',
#     'Cooks and cold-buffet managers',
#     'Waiters',
#     'Bartenders',
#     'Hairdressers',
#     'Beauticians and related workers',
#     'Masseurs and massage therapists',
#     'Foot therapists',
#     'Beauty and body therapists professionals not elsewhere classified',
#     'Cleaning supervisors and housekeepers',
#     'Building caretakers',
#     'Undertakers and embalmers',
#     'Personal services workers not elsewhere classified',
#     'Shopkeepers and shop supervisors, selling in stores',
#     'shop sales, groceries',
#     'shop sales, specialty stores',
#     'Opticians assistants',
#     'Petrol station personnel',
#     'Rental salespersons',
#     'Pharmacy technicians',
#     'Cashiers and related clerks',
#     'Event salespeople and shop demonstrators',
#     'Telemarketers',
#     'Child care workers',
#     'Teachers aides',
#     'Assistant nurses, home care and homes for the elderly',
#     'Assistant nurses, rehabilitation',
#     'Assistant nurses, hospital ward',
#     'Assistant nurses, clinic',
#     'Assistant nurses, children',
#     'Ambulance attendants',
#     'Home-based personal care and related workers',
#     'Attendants',
#     'Personal care providers',
#     'Personal assistants',
#     'Personal care workers in health services not elsewhere classified',
#     'Dental nurses',
#     'Firefighters',
#     'Prison guards',
#     'Security guards',
#     'Emergency call operators',
#     'Protective services workers not elsewhere classified',
#     'Field crop and vegetable growers',
#     'Gardeners, cultivation',
#     'Gardeners, parks and grounds',
#     'Livestock and dairy producers',
#     'Pet breeders and keepers',
#     'Animal breeders and related workers not elsewhere classified',
#     'Mixed crop and animal breeders',
#     'Forestry and related workers',
#     'Fish farmers',
#     'Fishermen',
#     'Woodworkers, carpenters',
#     'Bricklayers and related workers',
#     'Concrete placers, concrete finishers and related workers',
#     'Rail and road construction workers',
#     'Construction diver',
#     'Scaffold builders',
#     'Building frame and related trades workers not elsewhere classified',
#     'Roofers',
#     'Floor layers',
#     'Insulation workers',
#     'Glaziers',
#     'Plumbing and central heating fitters',
#     'Heating and air conditioning mechanics',
#     'Painters and related workers',
#     'Painters and industrial painters',
#     'Chimney sweepers',
#     'Building structure cleaners and related workers',
#     'Metal moulders and related workers',
#     'Welders and flame cutters',
#     'Sheet metal workers, building and ventilation',
#     'Sheet metal workers',
#     'Steel structure erectors and heavy plate workers',
#     'Blacksmiths, hammersmiths and forging press workers',
#     'Toolmakers and related workers',
#     'Machine-tool operators',
#     'Metal polishers, wheel grinders and tool sharpeners',
#     'Vehicle mechanics and repairers',
#     'Aircraft mechanics and repairers',
#     'Agricultural and industrial machinery mechanics and repairers',
#     'Precision-instrument makers and repairers',
#     'Jewellery and precious metal workers',
#     'Musical instrument makers and other handicraft workers',
#     'Pre-press technicians',
#     'Printers',
#     'Bookbinders and related workers',
#     'Electricians, installation and service',
#     'Electrical mechanics and fitters',
#     'Electrical line installers and repairers',
#     'Electronics repairers and telecom electricians',
#     'Wood treaters',
#     'Cabinet-makers and related workers',
#     'Machine operator, Wood-products',
#     'Tailors and related workers',
#     'Sewers, embroiderer and related workers',
#     'Upholsterers and related workers',
#     'Leather craft workers, shoemakers and related workers',
#     'Butchers, fishmongers and related food preparers',
#     'Bakers, pastry-cooks and confectionery makers',
#     'Food and beverage tasters and graders',
#     'Other food processors',
#     'Miners and quarries workers',
#     'Mineral and stone processing plant operators',
#     'Well drillers and borers and related workers',
#     'Machine operator, cement, stone and other mineral products',
#     'Shot firers and blasters',
#     'Stonemasons, stone cutters, splitters and carvers',
#     'Machine operators, metal finishing, plating and coating ',
#     'Metal melter and rolling-mill operators',
#     'Metal processing plant operators not elsewhere classified',
#     'Machine operators, pharmaceutical products ',
#     'Machine operators, chemical and photographic products ',
#     'Machine operators, rubber products ',
#     'Machine operators, plastic products ',
#     'Machine operators, paper products ',
#     'Machine operators, bleaching, dyeing and cleaning ',
#     'Machine operators not elsewhere classified, textile, fur and leather products',
#     'Machine operators, meat- and fish-processing ',
#     'Machine operators, dairy-products ',
#     'Machine operators, baked-goods, cereal and chocolate-products ',
#     'Machine operators not elsewhere classified, food and related products ',
#     'Paper pulp plant operators',
#     'Papermaking plant operators',
#     'Wood processing, sawmill and plywood plant operators',
#     'Machine operators, wood treaters ',
#     'Machine operators, packing, bottling and labelling',
#     'Machine operators not elsewhere classified, stationary plant and ',
#     'Power production and water treatment plant operators',
#     'Chemical processing plant controllers',
#     'Metal production process controllers',
#     'Process control technicians not elsewhere classified',
#     'Mechanical machinery assemblers',
#     'Electrical and electronic equipment assemblers',
#     'Metal-, rubber- and plastic-products assemblers',
#     'Wood and related products assemblers',
#     'Assemblers not elsewhere classified',
#     'Train operator',
#     'Railway, signal and switch operators',
#     'Taxi, car, and van drivers',
#     'Motorcycle, bicycle drivers and other automobile drivers not elsewhere classified',
#     'Bus and tram drivers',
#     'Heavy truck and lorry drivers',
#     'Forestry and agricultural machinery operators',
#     'Heavy Equipment Operators',
#     'Crane, hoist and related plant operators',
#     'Fork-lift drivers',
#     'Ships deck crews and related workers',
#     'Cleaners and helpers in offices, hotels and other establishments',
#     'Maid, nanny and related workers',
#     'Car reconditioning labourers, window cleaners and other hand cleaning workers',
#     'Berry pickers and planters',
#     'Construction labourers',
#     'Manufacturing labourers',
#     'Dock labourers',
#     'Ground personnel, movers and stockers',
#     'Pizza makers and fast food preparers',
#     'Restaurant and kitchen helpers',
#     'Café and confectionery assistants',
#     'Street and market vendors',
#     'Recycling collectors',
#     'Leaflet and newspaper distributors',
#     'Janitors and related workers',
#     'Other service workers not elsewhere classified',
#     'occupations unidentifiable'],
#    'elimination': True},
#   {'code': 'UtbNivaSun2020',
#    'text': 'level of education SUN 2020',
#    'values': ['1', '2', '3', '4', '5', '6', '7', 'US'],
#    'valueTexts': ['primary and secondary education less than 9 years (ISCED97 1)',
#     'primary and secondary education 9-10 years (ISCED97 2)',
#     'upper secondary education, 2 years or less (ISCED97 3C)',
#     'upper secondary education 3 years (ISCED97 3A)',
#     'post-secondary education, less than 3 years (ISCED97 4+5B)',
#     'post-secondary education 3 years or more (ISCED97 5A)',
#     'post-graduate education (ISCED97 6)',
#     'no information about level of educational attainment'],
#    'elimination': True},
#   {'code': 'Alder',
#    'text': 'age',
#    'values': ['16-24',
#     '25-29',
#     '30-34',
#     '35-39',
#     '40-44',
#     '45-49',
#     '50-54',
#     '55-59',
#     '60-64',
#     '065-69'],
#    'valueTexts': ['16-24 years',
#     '25-29 years',
#     '30-34 years',
#     '35-39 years',
#     '40-44 years',
#     '45-49 years',
#     '50-54 years',
#     '55-59 years',
#     '60-64 years',
#     '65-69 years'],
#    'elimination': True},
#   {'code': 'Kon',
#    'text': 'sex',
#    'values': ['1', '2'],
#    'valueTexts': ['men', 'women'],
#    'elimination': True},
#   {'code': 'ContentsCode',
#    'text': 'observations',
#    'values': ['000006Y4'],
#    'valueTexts': ['Number']},
#   {'code': 'Tid',
#    'text': 'year',
#    'values': ['2020', '2021', '2022', '2023'],
#    'valueTexts': ['2020', '2021', '2022', '2023'],
#    'time': True}]}

# %%
var_ = scb.get_variables()

# %%
occupations_key, occupations = next(iter(var_.items()))

# %%
clean_key = occupations_key.replace(" ", "")

# %%
# Years can be strings; coerce to int safely and pick max
def coerce_year(y):
    try:
        return int(y)
    except Exception:
        return None


years = [coerce_year(y) for y in var_["year"]]
years = [y for y in years if y is not None]
latest_year = str(max(years))

# ========= 3) Build query (match exact variable names) ========= #

scb.set_query(
    **{
        clean_key: occupations,
        "year": [latest_year],
    }
)

# %%
scb_data = scb.get_data()
scb_fetch = scb_data["data"]

# %%
codes = scb.get_query()["query"][0]["selection"]["values"]
occ_dict = dict(zip(codes, occupations))

# %%
# CREATING CLEANED DATAFRAME
records = []
for r in scb_fetch:
    code, year = r["key"][:2]  # occupation code, year
    name = occ_dict.get(code, code)
    value = r["values"][0]              # raw string
    records.append({"code_4": code, "occupation": name, "year": year, "value": value})

df = pd.DataFrame(records)
df = df[df["code_4"] != "0002"].reset_index(drop=True) ## remove unidentified group

# %%
# Code formatting
df["code_4"] = df["code_4"].astype(str).str.zfill(4)
df["code_3"] = df["code_4"].str[:3]
df["code_2"] = df["code_4"].str[:2]
df["code_1"] = df["code_4"].str[0]
df["value"]  = df["value"].astype(int)

# %%
# Mapping: level → column name
level_map = {4: "code_4", 3: "code_3", 2: "code_2", 1: "code_1"}

level_frames = []
for level, column in level_map.items():
    # Sum values (employment) within each parent group
    level_df = (
        df.groupby(["year", column], as_index=False)["value"]
        .sum()
        .rename(columns={column: "code"})
    )
    level_df["level"] = level
    level_frames.append(level_df)

# Combine all levels 1–4 into unified taxonomy format
df = (
    pd.concat(level_frames, ignore_index=True)
    .assign(taxonomy=TAX_ID)[["taxonomy", "year", "level", "code", "value"]]
    .sort_values(["year", "level", "code"])
    .reset_index(drop=True)
)

# %%
out_path = ROOT / "data" / "02_scb_data" / f"{TAX_ID}_weights_en_{latest_year}.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(out_path, index=False)
print(f"Wrote: {out_path.resolve()}")
# Out:
# Wrote: /media/jojo/DataDisk/2_Work/1_RA_Work/data/02_scb_data/ssyk2012_weights_en_2023.csv
